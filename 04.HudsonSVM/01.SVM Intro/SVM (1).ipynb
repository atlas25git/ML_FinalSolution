# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Saving figure higher_dimensions_plot

# %% [markdown]
# Above image potrays on left the boundaries possible by using three possible linear classifiers,
# In contrast the one on right represents the one possible by the use of SVM.
#
# We can think of an SVM classifier as fitting the
# widest possible street (represented by the parallel dashed lines) between the classes and adding more training instances “off the street” will not affect the decision
# boundary at all
# This is called large margin classification.

# %% [markdown]
# # SVMs are sensitive to scaling:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Soft Margin Classification
#
# The objective is to find a good balance
# between keeping the street as large as possible and limiting the margin violations

# %% [markdown]
# 1.If we strictly impose that all instances must be off the street and on the right side, this
# is called hard margin classification:
# First, it only works if the data is linearly separable. Second, it is sensitive to
# outliers.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# C is a hyperparameter in scikit learn implementation of SVM, lower C corresponds to higher margin violation, or soft margin classification:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The model on the left would generalize better.
#
# If SVM model is overfitting, you can try regularizing it by
# reducing C.
#
#
# Unlike Logistic Regression classifiers, SVM classifiers do not output
# probabilities for each class.

# %% [markdown]
# Instead of using the LinearSVC class, we could use the SVC class with a linear kernel.
# When creating the SVC model, we would write SVC(kernel="linear", C=1). Or we
# could use the SGDClassifier class, with SGDClassifier(loss="hinge", alpha=1/
# (m*C)). This applies regular Stochastic Gradient Descent (see Chapter 4) to train a
# linear SVM classifier. It does not converge as fast as the LinearSVC class, but it can be
# useful to handle online classification tasks or huge datasets that do not fit in memory
# (out-of-core training).

# %% [markdown]
# #Non Linear SVM Classification

# %% [markdown]
# Generally one way to deal with no linearly seprable data is by adding more features as was the case in polynomial linear reg.

# %%
X1D = np.linspace(-4, 4, 9).reshape(-1, 1)
X2D = np.c_[X1D, X1D**2]
y = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

plt.figure(figsize=(10, 3))

plt.subplot(121)
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.plot(X1D[:, 0][y==0], np.zeros(4), "bs")
plt.plot(X1D[:, 0][y==1], np.zeros(5), "g^")
plt.gca().get_yaxis().set_ticks([])
plt.xlabel(r"$x_1$", fontsize=20)
plt.axis([-4.5, 4.5, -0.2, 0.2])

plt.subplot(122)
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.plot(X2D[:, 0][y==0], X2D[:, 1][y==0], "bs")
plt.plot(X2D[:, 0][y==1], X2D[:, 1][y==1], "g^")
plt.xlabel(r"$x_1$", fontsize=20)
plt.ylabel(r"$x_2$  ", fontsize=20, rotation=0)
plt.gca().get_yaxis().set_ticks([0, 4, 8, 12, 16])
plt.plot([-4.5, 4.5], [6.5, 6.5], "r--", linewidth=3)
plt.axis([-4.5, 4.5, -1, 17])

plt.subplots_adjust(right=1)

save_fig("higher_dimensions_plot", tight_layout=False)
plt.show()
# Out:
# Saving figure higher_dimensions_plot
